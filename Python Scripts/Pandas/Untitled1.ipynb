# %% [markdown]
# ## Pandas
# - Alta performace e fácil uso para trabalhar com dados
# - Tem muitas coisas que lembram o Excel
# - O DataFrame é usado em várias outras bibliotecas de Ciencias de Dados
# - https://pandas.pydata.org/
#
# - O pandas vai desde a importação da base, passando por toda a análise exploratória até a exibição de gráficos

# %%
import pandas as pd

# %%
#importar uma base em csv
base = pd.read_csv('servidores_2024.csv')

# %%
#visualizando as primeiras linhas
base.head(1000)
# Out:
#     NOME                                                                          \
# 0    ANTONIO SERGIO BELTRAO MAFRA                  ...
# 1    CARLOS EDUARDO GUIMARAES LOPES                ...
# 2    ANASTACIA DA SILVA SANTOS                     ...
# 3    ANTONIO MARCONI LEMOS DA SILVA                ...
# 4    EMERSON CARVALHO DE LIMA                      ...
# ..                                                 ...
# 995  JOSE HELIO PAIVA                              ...
# 996  FRANCISCO DAS CHAGAS CARNEIRO DA COSTA        ...
# 997  MARIA TEREZINHA CHAGAS BEZERRA                ...
# 998  MARIA CELINA DUTRA GUEDES                     ...
# 999  MARIA DE FATIMA MAIA                          ...
#
#       ORGAO                                              CARGO  \
# 0       CGE  AUDITOR DE CONTROLE INTERNO                   ...
# 1       CGE  AUDITOR DE CONTROLE INTERNO                   ...
# 2       CGE  AUDITOR DE CONTROLE INTERNO                   ...
# ...

# %%
base.tail()
# Out:
#        NOME                                                                          \
# 178881  MARIA APARECIDA MIRANDA OLIVEIRA              ...
# 178882  DAVI SANTOS BANDEIRA                          ...
# 178883  FRANCISCA HELENA AMBROSIO DE MELO             ...
# 178884  JAIR MARCELINO FERREIRA                       ...
# 178885  JULIANA OLIVEIRA LEITAO                       ...
#
#         ORGAO  CARGO                         SITUACAO   SALARIO BASE  \
# 178881    NaN    NaN                              NaN            NaN
# 178882    NaN    NaN                              NaN            NaN
# 178883    NaN    NaN                              NaN            NaN
# 178884    NaN    NaN                              NaN            NaN
# 178885    NaN    NaN                              NaN            NaN
#
#          DESCONTO   SALARIO BRUTO   EMPRESTIMOS   SALARIO LIQUIDO   IR
# 178881        NaN             NaN           NaN               NaN     NaN
# ...

# %%
base02 = pd.read_csv('servidores_2024.csv')

# %%
base02.head()
# Out:
#   NOME                                                                          \
# 0  ANTONIO SERGIO BELTRAO MAFRA                  ...
# 1  CARLOS EDUARDO GUIMARAES LOPES                ...
# 2  ANASTACIA DA SILVA SANTOS                     ...
# 3  ANTONIO MARCONI LEMOS DA SILVA                ...
# 4  EMERSON CARVALHO DE LIMA                      ...
#
#    ORGAO                                              CARGO  \
# 0    CGE  AUDITOR DE CONTROLE INTERNO                   ...
# 1    CGE  AUDITOR DE CONTROLE INTERNO                   ...
# 2    CGE  AUDITOR DE CONTROLE INTERNO                   ...
# 3    CGE  AUDITOR DE CONTROLE INTERNO                   ...
# 4    CGE  AUDITOR DE CONTROLE INTERNO                   ...
#
#                           SITUACAO   SALARIO BASE   DESCONTO   SALARIO BRUTO  \
# 0                            Ativo        2773.43       0.00         2773.43
# 1                            Ativo       20301.61       0.00        20301.61
# ...

# %%
base02 = base.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

print(base02)
# Out:
#        NOME                                                                          \
# 0                            ANTONIO SERGIO BELTRAO MAFRA
# 1                          CARLOS EDUARDO GUIMARAES LOPES
# 2                               ANASTACIA DA SILVA SANTOS
# 3                          ANTONIO MARCONI LEMOS DA SILVA
# 4                                EMERSON CARVALHO DE LIMA
# ...                                                   ...
# 178881  MARIA APARECIDA MIRANDA OLIVEIRA              ...
# 178882  DAVI SANTOS BANDEIRA                          ...
# 178883  FRANCISCA HELENA AMBROSIO DE MELO             ...
# 178884  JAIR MARCELINO FERREIRA                       ...
# 178885  JULIANA OLIVEIRA LEITAO                       ...
#
#         ORGAO                        CARGO                         SITUACAO  \
# 0         CGE  AUDITOR DE CONTROLE INTERNO                            Ativo
# 1         CGE  AUDITOR DE CONTROLE INTERNO                            Ativo
# ...

# %%
base02.head(200)
# Out:
#     NOME                                                                          \
# 0                         ANTONIO SERGIO BELTRAO MAFRA
# 1                       CARLOS EDUARDO GUIMARAES LOPES
# 2                            ANASTACIA DA SILVA SANTOS
# 3                       ANTONIO MARCONI LEMOS DA SILVA
# 4                             EMERSON CARVALHO DE LIMA
# ..                                                 ...
# 195                        ROBERIO PEREIRA DE OLIVEIRA
# 196                              ISRAEL ALVES DE SOUSA
# 197                          JARDEL GONCALVES DE SOUSA
# 198                        GLAYDSTON FERREIRA DA SILVA
# 199                    GEORGE MICHAEL BARBOZA DA SILVA
#
#      ORGAO                        CARGO                         SITUACAO  \
# 0      CGE  AUDITOR DE CONTROLE INTERNO                            Ativo
# 1      CGE  AUDITOR DE CONTROLE INTERNO                            Ativo
# ...

# %%
base02.shape
# Out:
# (178886, 10)

# %%
display(base02.head(100000))
# Out:
#       NOME                                                                          \
# 0                           ANTONIO SERGIO BELTRAO MAFRA
# 1                         CARLOS EDUARDO GUIMARAES LOPES
# 2                              ANASTACIA DA SILVA SANTOS
# 3                         ANTONIO MARCONI LEMOS DA SILVA
# 4                               EMERSON CARVALHO DE LIMA
# ...                                                  ...
# 99995                        SEBASTIANA PAULINO DA SILVA
# 99996                      JOSE DOMINGOS ARAUJO FERREIRA
# 99997                       MARIA CELESTE DA SILVA VIANA
# 99998                              JOSE EPITACIO QUEIROZ
# 99999                      ANTONIO FERNANDO BATISTA LIMA
#
#        ORGAO                        CARGO                         SITUACAO  \
# 0        CGE  AUDITOR DE CONTROLE INTERNO                            Ativo
# 1        CGE  AUDITOR DE CONTROLE INTERNO                            Ativo
# ...

# %%
cargos = base02[['CARGO', 'SALARIO BASE']]

print(base02)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11276\3503072572.py in <module>
# ----> 1 cargos = base02[['CARGO', 'SALARIO BASE']]
#       2
#       3 print(base02)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ...

# %%
print(base02.columns)
# Out:
# Index(['NOME                                                                        ',
#        ' ORGAO', ' CARGO', '                        SITUACAO', ' SALARIO BASE',
#        ' DESCONTO', ' SALARIO BRUTO', ' EMPRESTIMOS', ' SALARIO LIQUIDO',
#        ' IR   '],
#       dtype='object')

# %%
# Remover espaços extras e ajustar para maiúsculas/minúsculas
base02.columns = base02.columns.str.strip().str.upper()

# %%
print(base02.columns)
# Out:
# Index(['NOME', 'ORGAO', 'CARGO', 'SITUACAO', 'SALARIO BASE', 'DESCONTO',
#        'SALARIO BRUTO', 'EMPRESTIMOS', 'SALARIO LIQUIDO', 'IR'],
#       dtype='object')

# %%
display(base02.head(100000))
# Out:
#                                  NOME  ORGAO                        CARGO  \
# 0        ANTONIO SERGIO BELTRAO MAFRA    CGE  AUDITOR DE CONTROLE INTERNO
# 1      CARLOS EDUARDO GUIMARAES LOPES    CGE  AUDITOR DE CONTROLE INTERNO
# 2           ANASTACIA DA SILVA SANTOS    CGE  AUDITOR DE CONTROLE INTERNO
# 3      ANTONIO MARCONI LEMOS DA SILVA    CGE  AUDITOR DE CONTROLE INTERNO
# 4            EMERSON CARVALHO DE LIMA    CGE  AUDITOR DE CONTROLE INTERNO
# ...                               ...    ...                          ...
# 99995     SEBASTIANA PAULINO DA SILVA  CBMCE                   COZINHEIRO
# 99996   JOSE DOMINGOS ARAUJO FERREIRA  CBMCE                   SUBTENENTE
# 99997    MARIA CELESTE DA SILVA VIANA  CBMCE      AGENTE DE ADMINISTRACAO
# 99998           JOSE EPITACIO QUEIROZ  CBMCE                      CAPITAO
# 99999   ANTONIO FERNANDO BATISTA LIMA  CBMCE                   SUBTENENTE
#
#          SITUACAO  SALARIO BASE  DESCONTO  SALARIO BRUTO  EMPRESTIMOS  \
# ...

# %%
# Filtrar por 'CARGO' e selecionar as colunas 'nome' e 'SALARIO BASE'
analistas = base02[base02['CARGO'] == 'ANALISTA DE GESTAO DE TECNOLOGIA DA INFORMACAO'][['NOME', 'CARGO', 'SALARIO BASE', 'ORGAO']].head(1000)

display(analistas)
# Out:
#                                           NOME  \
# 107238                   EDMAR MENDES DA SILVA
# 107241         GUILHERME SOARES QUINDERE MOURA
# 107242                JULIO CESAR LIMA BATISTA
# 107243              ADERSON BARROSO DE ALENCAR
# 107244                LEVINDO JOSE GARCIA NETO
# 107246      LUCIA POMPEU DE VASCONCELOS CASTRO
# 107247                 ROGERIO RIBEIRO SARAIVA
# 107263                  ARIANA FALCAO DA SILVA
# 107265               JOAO BOSCO ALVES DA SILVA
# 107266               LUCIA MARIA BESERRA VERAS
# 107275             ANTONIO CARLOS LEITE SOARES
# 107283          SERGIO VICENTE DE MATTOS BRITO
# 107289                 ANA LUCIA PEREIRA GOMES
# 107290         REGINA ESTELA BENEVIDES DE LIMA
# 107291            VERA LUCIA CARNEIRO DE SOUSA
# 107311         JOAO JOSE VASCO PEIXOTO FURTADO
# 107312              SILVIA KATAOKA DE OLIVEIRA
# 107313             IRAM CARVALHO DO NASCIMENTO
# 107316          FRANCISCO AUGUSTO ANDRADE MAIA
# ...
